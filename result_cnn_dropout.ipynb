# %%
import chainer
chainer.__version__
# Out:
# '1.7.2'

# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2015 NVIDIA Corporation
# Built on Tue_Aug_11_14:27:32_CDT_2015
# Cuda compilation tools, release 7.5, V7.5.17

# %%
# !python train.py -g 0 -m cnn -b 128 -p cnn --optimizer adam --iter 300 --lr_decay_iter 100
# Out:
# loading dataset...
# start training
# epoch 0 done
# train loss: 3.11401703419 error: 82.2044444452
# valid loss: 1.97585976238 error: 73.88
# test  loss: 1.9643712513 error: 72.89
# elapsed time: 7.718116
# epoch 1 done
# train loss: 1.9225164391 error: 71.5977777762
# valid loss: 1.81045582733 error: 66.02
# test  loss: 1.78167553596 error: 65.16
# elapsed time: 7.253204
# epoch 2 done
# train loss: 1.82925441494 error: 67.7066666672
# valid loss: 1.74166778603 error: 64.26
# test  loss: 1.71424070377 error: 63.31
# elapsed time: 7.417758
# epoch 3 done
# train loss: 1.76915756433 error: 65.0933333339
# valid loss: 1.69251437283 error: 62.48
# test  loss: 1.67176790504 error: 61.08
# elapsed time: 7.313996
# epoch 4 done
# train loss: 1.72606077574 error: 62.9911111101
# valid loss: 1.61463458004 error: 59.02
# test  loss: 1.60576329689 error: 58.22
# elapsed time: 7.425928
# epoch 5 done
# train loss: 1.67035865116 error: 60.9044444439
# valid loss: 1.58843809395 error: 58.04
# ...
